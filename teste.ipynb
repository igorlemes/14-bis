# %%
import lib14bis as lb
from lib14bis.processing.enhance import ImageMock, Enhance

# %%
img = ImageMock("lib14bis/data/cat.jpg")

# %%
img.show()
img2 = img

# %%
img2.data = Enhance.sharpen(img)
img2.show()

# %%
img3 = Enhance.multiply(img2, [2., 1., 1.])
img3.show()
