# %%
import lib14bis as lb
from lib14bis.processing.enhance import Enhance
from lib14bis.image.image import Image, Data, Unzip

# %%
img = Image("lib14bis/data/13916-ImageSet.zip")
img.show()

# %%
img = Enhance.upscale(img)
img.show()

# %%
img = Enhance.sharpen(img,2)
img.show()

# %%
img = Enhance.multiply(img, [1.2, 1.1, 1.3])
img.show()

# %%
img = Enhance.contrast(img,2,10)
img.show()

# %%
img.save("result.png")
